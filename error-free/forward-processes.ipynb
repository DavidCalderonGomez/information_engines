# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('text', usetex=False)
rc('font', family='serif')

# %%
import matplotlib.pyplot as plt
import pandas as pd

datas=pd.read_csv("forward-process-error.txt", delim_whitespace=True, header=None,encoding="utf-16")
# Assign column names for clarity
data=datas.iloc[:-1] 
work=datas.iloc[-1,0]
data.columns = ['Time', 'Position', 'Potential']

# Plotting the time series
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Position'], label='Position',color='orange', linewidth=0.75)
plt.plot(data['Time'], data['Potential'], label=f'Potential \n\n $W = {work}$',color='blue', linewidth=0.75)

# Adding labels, title, and legend
plt.title(rf'Single forward process with noise = 0.1 and $ \alpha ^* = 1.5 $', fontsize=14)
plt.xlabel(r'Time', fontsize=12)
plt.ylabel(r'Position', fontsize=12)
plt.legend(fontsize=10)
# Display the plot
#plt.show()
plt.savefig('forward-process-error-optimal-single.pdf',format='pdf')
# Out:
# C:\Users\dcald\AppData\Local\Temp\ipykernel_11148\4198291676.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   datas=pd.read_csv("forward-process-error.txt", delim_whitespace=True, header=None,encoding="utf-16")
