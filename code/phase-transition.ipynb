# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('text', usetex=True)
rc('font', family='serif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter

# Load the dataset
data = pd.read_csv("phase-transition.txt", delim_whitespace=True, header=None, encoding="utf-16")

# Assign column names for clarity
data.columns = ['SNR', 'gain']

# Generate the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['SNR'], data['gain'], color='orange', label='optimal gain')
plt.xscale('log')
# Use ScalarFormatter to display normal numbers
plt.gca().xaxis.set_major_formatter(ScalarFormatter())

# Adding labels, title, and legend
plt.title(rf'Optimal gain $\alpha^*$ vs noise SNR',fontsize=24,pad=15)
plt.xlabel('SNR',fontsize=20)
plt.ylabel(rf'$\alpha^*$',fontsize=20)
plt.legend(fontsize=18)

# Display the plot
#plt.show()
plt.savefig('phase-transition.pdf', format='pdf')
# Out:
# C:\Users\dcald\AppData\Local\Temp\ipykernel_21156\550134243.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv("phase-transition.txt", delim_whitespace=True, header=None, encoding="utf-16")
