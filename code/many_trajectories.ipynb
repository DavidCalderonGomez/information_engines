# %%
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_csv('many_trajectories.dat', delim_whitespace=True, header=None)
# Assign column names for clarity
data.columns = ['Time'] + [f'Series_{i}' for i in range(1, len(data.columns))]

# Plotting the time series for all columns except 'Time'
plt.figure(figsize=(10, 6))

for column in data.columns[1:]:  # Iterate over series columns
    plt.plot(data['Time'], data[column], color='red',linewidth=0.25)

# Adding labels, title, and legend
plt.title(r'Many trajectories $\alpha=1.5$, SNR=11', fontsize=14)
plt.xlabel(r'Time ts', fontsize=12)
plt.ylabel(r'Position', fontsize=12)
#plt.legend(fontsize=10)
# Display the plot
#plt.show()
plt.savefig('many_trajectory.pdf',format='pdf')
# Out:
# /tmp/ipykernel_13812/3869163530.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data=pd.read_csv('many_trajectories.dat', delim_whitespace=True, header=None)
