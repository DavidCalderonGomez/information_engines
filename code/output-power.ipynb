# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('text', usetex=True)
rc('font', family='serif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter

# Load the dataset
data = pd.read_csv("output-power.txt", delim_whitespace=True, header=None, encoding="utf-16")

# Assign column names for clarity
data.columns = ['SNR', 'power']

# Generate the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['SNR'], data['power'], color='orange', label=r'output power $ \langle\dot{F}\rangle$')
plt.xscale('log')
# Use ScalarFormatter to display normal numbers
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.axhline(y=0.3, color='#53729b', linestyle='dashed', linewidth=1, label= r'$\langle \dot{F} \rangle =0.29$')

# Adding labels, title, and legend
plt.title(r'Output power average $\langle \dot{F} \rangle$ vs noise SNR',fontsize=24,pad=15)
plt.xlabel('SNR',fontsize=20)
plt.ylabel(r'$\langle \dot{F} \rangle (k_B T) / \tau_r$',fontsize=20)
plt.legend(fontsize=18)

# Display the plot
#plt.show()
plt.savefig('output-power.pdf', format='pdf')
# Out:
# C:\Users\dcald\AppData\Local\Temp\ipykernel_3272\3404575596.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv("output-power.txt", delim_whitespace=True, header=None, encoding="utf-16")
