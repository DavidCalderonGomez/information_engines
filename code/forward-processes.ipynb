# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('text', usetex=True)
rc('font', family='serif')

# %%
import matplotlib.pyplot as plt
import pandas as pd

datas=pd.read_csv("forward-process.txt", delim_whitespace=True, header=None,encoding="utf-16")
# Assign column names for clarity
data=datas.iloc[:-1] 
work=datas.iloc[-1,0]
data.columns = ['Time', 'Position', 'Potential']

#color HEX: #53729b
# Plotting the time series
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Position'], label='Position',color='orange', linewidth=0.75)
plt.plot(data['Time'], data['Potential'], label=f'Potential \n\n $W = {work}$',color='#53729b', linewidth=0.75)

# Adding labels, title, and legend
plt.title(rf'Single forward process with no noise and $\alpha^* = 2 $', fontsize=24,pad=15)
plt.xlabel(r'Time', fontsize=20)
plt.ylabel(r'Position', fontsize=20)
plt.legend(fontsize=18)
# Display the plot
#plt.show()
plt.savefig('forward-process.pdf',format='pdf')
# Out:
# C:\Users\dcald\AppData\Local\Temp\ipykernel_13840\1778695732.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   datas=pd.read_csv("forward-process.txt", delim_whitespace=True, header=None,encoding="utf-16")
